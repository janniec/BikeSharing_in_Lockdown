# %% [markdown]
# # Imports

# %%
import pickle
import visualize_plots as vp 
# Import visualization function from module

# %% [markdown]
# # Data

# %%
#Open pickle file with dataframe of cleaned divvy trips data
with open("data/divvy_trips.pkl", 'rb') as picklefile:
    df = pickle.load(picklefile)

# %% [markdown]
# # Visualizations

# %% [markdown]
# ## Ride counts by week

# %%
ride_count_by_week = vp.plot_pivot(df, 'ride_id', 'count', 'Ride Counts')
# ride_id is a unique id for each ride
# applying the visualization function to look at the total number of bicycle rentals across the weeks of 2020
# Out:
# /home/jyychang/pandemic_divvy/visualize_plots.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['0', ' 2019-12-29', ' 2020-01-27', \

# %% [markdown]
# ## Mean Duration by Week

# %%
mean_duration_by_week = vp.plot_pivot(df, 'duration_minutes', 'mean', 'Mean Duration (Minutes)')
# applying the visualization function to look at the mean duration across the weeks of 2020
# because we already cleaned out the rides that were instant returns or rides that were longer than 24 hours,
# there wasn't a drastic difference between the mean and median
# Out:
# /home/jyychang/pandemic_divvy/visualize_plots.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   # applying the aggfunc, like "sum", to our designated value such as "duration"
